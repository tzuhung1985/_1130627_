# %%
print("Hello! Python")
# Out:
# Hello! Python

# %%
import pandas as pd
df1=pd.read_csv("aqx_p_488.csv")
df1[["sitename","county","status","aqi","pm2.5_avg"]]
# Out:
#      sitename county status  aqi  pm2.5_avg
# 0      屏東(枋山)    屏東縣     良好   16        0.8
# 1    大甲（日南國小）    臺中市     良好   12        2.7
# 2      新北(樹林)    新北市     良好   35       10.7
# 3      屏東（琉球）    屏東縣     良好   28        8.7
# 4      臺南（麻豆）    臺南市     良好   34       10.4
# ..        ...    ...    ...  ...        ...
# 995        頭份    苗栗縣     良好   29        9.0
# 996        新竹    新竹市     良好   27        6.4
# 997        竹東    新竹縣     良好   28        7.7
# 998        湖口    新竹縣     良好   33       10.3
# 999        龍潭    桃園市     良好   36       11.2
#
# [1000 rows x 5 columns]
